# %% [markdown]
# # AI Adoption & Productivity Analysis

# %%
import pandas as pd

df = pd.read_csv("D:\internship project\Ai productivity analysis clean file.csv")

# %%
df.shape
# Out:
# (30000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Employee_ID                   30000 non-null  int64
#  1   Age                           30000 non-null  int64
#  2   Industry                      30000 non-null  object
#  3   Job_Role                      30000 non-null  object
#  4   Experience_Years              30000 non-null  int64
#  5   Company_Size                  30000 non-null  object
#  6   Remote_Work_Type              30000 non-null  object
#  7   AI_Tools_Used                 30000 non-null  int64
#  8   Daily_AI_Usage_Hours          30000 non-null  float64
#  9   Primary_AI_Tool               30000 non-null  object
#  10  Tasks_Automated_Percent       30000 non-null  int64
#  11  Time_Saved_Per_Day_Minutes    30000 non-null  int64
# ...

# %%
df.head()
# Out:
#    Employee_ID  Age   Industry            Job_Role  Experience_Years  \
# 0            1   50       Tech          Consultant                14
# 1            2   45    Finance      Data Scientist                 2
# 2            3   43  Marketing          Consultant                11
# 3            4   24     Retail  Software Developer                 0
# 4            5   30  Education          Consultant                 4
#
#   Company_Size Remote_Work_Type  AI_Tools_Used  Daily_AI_Usage_Hours  \
# 0        Large           Onsite              2                   3.9
# 1        Large           Remote              4                   4.8
# 2        Small           Onsite              0                   1.5
# 3       Medium           Remote              2                   3.4
# 4        Large           Onsite              1                   3.4
#
#   Primary_AI_Tool  ...  Time_Saved_Per_Day_Minutes  \
# 0      Midjourney  ...                         102
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID                     0
# Age                             0
# Industry                        0
# Job_Role                        0
# Experience_Years                0
# Company_Size                    0
# Remote_Work_Type                0
# AI_Tools_Used                   0
# Daily_AI_Usage_Hours            0
# Primary_AI_Tool                 0
# Tasks_Automated_Percent         0
# Time_Saved_Per_Day_Minutes      0
# Learning_Time_Per_Week_Hours    0
# Meetings_Per_Day                0
# Work_Hours_Per_Day              0
# Job_Satisfaction                0
# Productivity_Change             0
# Salary_USD                      0
# Promotion_Last_Year             0
# Fear_of_AI_Replacing_Job        0
# Target                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Employee_ID                       int64
# Age                               int64
# Industry                         object
# Job_Role                         object
# Experience_Years                  int64
# Company_Size                     object
# Remote_Work_Type                 object
# AI_Tools_Used                     int64
# Daily_AI_Usage_Hours            float64
# Primary_AI_Tool                  object
# Tasks_Automated_Percent           int64
# Time_Saved_Per_Day_Minutes        int64
# Learning_Time_Per_Week_Hours    float64
# Meetings_Per_Day                  int64
# Work_Hours_Per_Day              float64
# Job_Satisfaction                 object
# Productivity_Change              object
# Salary_USD                        int64
# Promotion_Last_Year              object
# Fear_of_AI_Replacing_Job         object
# Target                           object
# dtype: object

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=20)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="Industry")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df, x="Company_Size")
# Out:
# <Axes: xlabel='Company_Size', ylabel='count'>

# %%
sns.countplot(data=df, x="Remote_Work_Type")
# Out:
# <Axes: xlabel='Remote_Work_Type', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="Primary_AI_Tool")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Numerical Analysis

# %%
sns.histplot(df["Salary_USD"])
# Out:
# <Axes: xlabel='Salary_USD', ylabel='Count'>

# %%
sns.histplot(df["Daily_AI_Usage_Hours"])
# Out:
# <Axes: xlabel='Daily_AI_Usage_Hours', ylabel='Count'>

# %%
sns.histplot(df["Time_Saved_Per_Day_Minutes"])
# Out:
# <Axes: xlabel='Time_Saved_Per_Day_Minutes', ylabel='Count'>

# %%
sns.histplot(df["Tasks_Automated_Percent"])
# Out:
# <Axes: xlabel='Tasks_Automated_Percent', ylabel='Count'>

# %% [markdown]
# # Correlation Analysis

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
df.groupby("Industry")["Salary_USD"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Industry'>

# %%
df.groupby("Industry")["Daily_AI_Usage_Hours"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Industry'>

# %%
df.groupby("Industry")["Time_Saved_Per_Day_Minutes"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Industry'>

# %%
sns.countplot(data=df,x="Job_Satisfaction")
# Out:
# <Axes: xlabel='Job_Satisfaction', ylabel='count'>

# %%
sns.countplot(data=df,x="Productivity_Change")
# Out:
# <Axes: xlabel='Productivity_Change', ylabel='count'>

# %%
sns.countplot(data=df,x="Fear_of_AI_Replacing_Job")
# Out:
# <Axes: xlabel='Fear_of_AI_Replacing_Job', ylabel='count'>

# %%
sns.countplot(data=df,x="Promotion_Last_Year")
# Out:
# <Axes: xlabel='Promotion_Last_Year', ylabel='count'>

# %% [markdown]
# # Outlier Detection

# %%
sns.boxplot(df["Salary_USD"])
# Out:
# <Axes: ylabel='Salary_USD'>

# %%
sns.boxplot(df["Experience_Years"])
# Out:
# <Axes: ylabel='Experience_Years'>

# %%
sns.boxplot(df["Work_Hours_Per_Day"])
# Out:
# <Axes: ylabel='Work_Hours_Per_Day'>

# %% [markdown]
# #Business Questions
# ###Answer questions such as:
#
# Which industry has the highest AI adoption?
# Which AI tool is most popular?
# Which industry saves the most time?
# Which company size uses AI the most?
# Which employees fear AI the most?
# Does AI improve productivity?
# Does AI reduce work hours?
# Does salary influence AI usage?
# Which industry has the highest job satisfaction?
# Which work type is most productive?

# %%
df.to_csv("Final_Cleaned_Data.csv", index=False)
